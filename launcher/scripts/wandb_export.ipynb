# %%
import wandb
from wandb.apis.public.runs import Run
from datetime import datetime, timedelta
import pandas as pd

PROJECT_URL = "https://wandb.ai/hyena/7b-context-extension"
ENTITY = "hyena"
PROJECT = "7b-context-extension"
runs: list = wandb.Api().runs(f"{ENTITY}/{PROJECT}")

# %%
pattern = "n32"
runs: list[Run] = [run for run in runs if pattern in run.name]

# %%
for run in runs:
    print(run.name, run.id)
# Out:
# n32-log-32K 20241109194350
# n32-linear-32K 20241110010914
# n32-evo1-32K 20241110022836
# n32-5x-32K 20241110042338
# n32-5x-32K 20241110054044

# %%
def convert_iso_to_dt(iso: str) -> datetime:
    return datetime.fromisoformat(iso)


HISTORY_KEYS = [
    "_step",
    "data/tokens_per_second_per_gpu",
    "runtime/iteration_time",
    "train/lm_loss",
    "validation/lm_loss",
]


def summarize_runs(runs: list[Run], num_samples=None, keys=HISTORY_KEYS):
    meta = []
    run_dict = {}
    for run in runs:
        metadata = run.metadata
        try:
            # Get start and end times
            start = metadata["startedAt"]
            # start = convert_iso_to_dt(start)
            #   start_key = start.strftime("%Y-%m-%d-%H:%M")
            # key = f"{run.name}_{start_key}"
            duration = timedelta(seconds=run.summary["_wandb"]["runtime"])
            #        end = start + duration
            #  end_key = end.strftime("%Y-%m-%d-%H:%M")

            # Get run history
            history = (
                pd.DataFrame(run.scan_history(keys=keys))
                if num_samples is None
                else run.history(keys=keys, samples=num_samples)
            )
            if len(history) == 0:
                continue
                print(f"Skipping {key} due to empty history")

            key = run.url
            run_dict[key] = {
                "start_dt": start,
                #           "end_dt": end,
                #     "start": start_key,
                #    "end": end_key,
                "metadata": metadata,
                "history": history,
            }

            # Print summary
            avg_tpt, avg_t = history.mean()[["data/tokens_per_second_per_gpu", "runtime/iteration_time"]]
            start_train_loss, end_train_loss = (
                history["train/lm_loss"].iloc[0],
                history["train/lm_loss"].iloc[-1],
            )
            start_val_loss, end_val_loss = (
                history["validation/lm_loss"].iloc[0],
                history["validation/lm_loss"].iloc[-1],
            )
            # Update run_dict with summary stats
            run_dict[key].update(
                {
                    "duration": duration.total_seconds() / 3600,
                    "avg_throughput": avg_tpt,
                    "avg_iteration_time": avg_t,
                    "start_train_loss": start_train_loss,
                    "end_train_loss": end_train_loss,
                    "start_val_loss": start_val_loss,
                    "end_val_loss": end_val_loss,
                }
            )

            header = f"{key}:\n Started at: {start} Duration: {duration.total_seconds()/3600:.2f}hrs"
            runtime = f"Avg Throughput: {avg_tpt:.2f} Avg Iteration Time: {avg_t:.2f}"
            losses = f"Start Train Loss: {start_train_loss:.2f} End Train Loss: {end_train_loss:.2f}\n Start Val Loss: {start_val_loss:.2f} End Val Loss: {end_val_loss:.2f}"
            print_str = "\n ".join([header, runtime, losses])
            print(print_str)
        except Exception as e:
            print(f"Error processing {run.name}: {e}")

    return run_dict

# %%
run_dict = summarize_runs(runs)
# Out:
# https://wandb.ai/hyena/7b-context-extension/runs/20241109194350:
#  Started at: 2024-11-10T03:43:51.300021Z Duration: 7.24hrs
#  Avg Throughput: 8163.33 Avg Iteration Time: 2.01
#  Start Train Loss: 1.04 End Train Loss: 1.00
#  Start Val Loss: 1.04 End Val Loss: 1.02
# https://wandb.ai/hyena/7b-context-extension/runs/20241110010914:
#  Started at: 2024-11-10T09:09:15.689373Z Duration: 6.52hrs
#  Avg Throughput: 8188.92 Avg Iteration Time: 2.00
#  Start Train Loss: 1.04 End Train Loss: 1.01
#  Start Val Loss: 1.04 End Val Loss: 1.02
# https://wandb.ai/hyena/7b-context-extension/runs/20241110022836:
#  Started at: 2024-11-10T10:28:37.205489Z Duration: 5.20hrs
#  Avg Throughput: 8191.73 Avg Iteration Time: 2.00
#  Start Train Loss: 1.03 End Train Loss: 1.05
#  Start Val Loss: 1.03 End Val Loss: 1.03
# Error processing n32-5x-32K: '_wandb'

# %%
summary_df = pd.DataFrame(run_dict).T

# %%
summary_df.history.iloc[0]
# Out:
#     _step  data/tokens_per_second_per_gpu  runtime/iteration_time  \
# 0     500                     8166.196378                2.006320
# 1    1000                     8142.628651                2.012127
# 2    1500                     8166.511001                2.006242
# 3    2000                     8162.448008                2.007241
# 4    2500                     8161.976262                2.007357
# 5    3000                     8162.131178                2.007319
# 6    3500                     8164.764871                2.006671
# 7    4000                     8159.314529                2.008012
# 8    4500                     8168.378271                2.005784
# 9    5000                     8156.239408                2.008769
# 10   5500                     8156.394687                2.008731
# 11   6000                     8159.115933                2.008061
# 12   6500                     8160.785022                2.007650
# 13   7000                     8168.118651                2.005847
# 14   7500                     8156.563719                2.008689
# 15   8000                     8171.533293                2.005009
# 16   8500                     8164.384036                2.006765
# 17   9000                     8167.188268                2.006076
# 18   9500                     8160.971876                2.007604
# 19  10000                     8165.484928                2.006494
# 20  10500                     8168.111855                2.005849
# 21  11000                     8165.275553                2.006546
# 22  11500                     8173.370392                2.004559
# 23  12000                     8170.096029                2.005362
# 24  12500                     8165.204729                2.006563
#
#     train/lm_loss  validation/lm_loss
# 0        1.042655            1.038076
# 1        1.042721            1.041353
# 2        1.047059            1.031628
# 3        1.031888            1.030769
# 4        1.029305            1.033385
# 5        1.055158            1.027669
# 6        1.029761            1.031546
# 7        1.013679            1.028609
# 8        1.043509            1.026533
# 9        1.031827            1.023422
# 10       1.012486            1.028155
# 11       1.040010            1.028343
# 12       1.024604            1.027187
# 13       1.025386            1.025810
# 14       1.013629            1.027246
# 15       1.015019            1.023504
# 16       1.029890            1.022437
# 17       1.019975            1.021797
# 18       1.005570            1.018324
# 19       1.047520            1.026764
# 20       0.999625            1.027638
# 21       1.010481            1.024994
# 22       1.014069            1.020212
# 23       1.010420            1.023035
# 24       0.995088            1.024392

# %%
d = summary_df.start_dt.iloc[-1]
d
# Out:
# '2024-11-04T08:17:39.311952Z'

# %%
from datetime import datetime
import pytz

# Original datetime string in UTC
utc_datetime_str = d
# Parse the string and set timezone to UTC
utc_datetime = datetime.strptime(utc_datetime_str, "%Y-%m-%dT%H:%M:%S.%fZ").replace(tzinfo=pytz.UTC)

# Convert to PST
pst_timezone = pytz.timezone("America/Los_Angeles")
pst_datetime = utc_datetime.astimezone(pst_timezone)

# Format to desired output
formatted_datetime = pst_datetime.strftime("%B %d, %Y at %I:%M:%S %p %Z")
print(formatted_datetime)
# Out:
# November 04, 2024 at 12:17:39 AM PST

# %%
# Convert to PST
pst_timezone = pytz.timezone("America/Los_Angeles")
pst_datetime = utc_datetime.astimezone(pst_timezone)

# Format to desired output
formatted_datetime = pst_datetime.strftime("%B %dth, %Y at %I:%M:%S %p %Z")
print(formatted_datetime)

# %%
# dt_fmt = "%Y-%m-%d-%H:%M"
# summary_df["start"] = summary_df["start"].map(lambda x: x.strftime(dt_fmt))
# summary_df["end"] = summary_df["end"].map(lambda x: x.strftime(dt_fmt))
summary_keys = list(set(summary_df.columns) - set(["history", "metadata"]))

# %%
col_order = [
    "start",
    "end",
    "duration",
    "avg_throughput",
    "avg_iteration_time",
    "start_train_loss",
    "end_train_loss",
    "start_val_loss",
    "end_val_loss",
]
summary_stats = summary_df[summary_keys][col_order]
summary_stats.to_csv("40b-train-summary.csv")
summary_df[col_order + ["metadata", "history"]].to_csv("40b-train-summary-full.csv")

# %%
summary_stats
# Out:
#                                                                start  \
# https://wandb.ai/hyena/40b-train/runs/202410271...  2024-10-27-23:22
# https://wandb.ai/hyena/40b-train/runs/202410271...  2024-10-28-00:27
# https://wandb.ai/hyena/40b-train/runs/202410280...  2024-10-28-07:36
# https://wandb.ai/hyena/40b-train/runs/202410280...  2024-10-28-16:09
# https://wandb.ai/hyena/40b-train/runs/202410281...  2024-10-29-00:10
# https://wandb.ai/hyena/40b-train/runs/202410281...  2024-10-29-00:41
# https://wandb.ai/hyena/40b-train/runs/202410290...  2024-10-29-11:37
# https://wandb.ai/hyena/40b-train/runs/202410292...  2024-10-30-05:08
# https://wandb.ai/hyena/40b-train/runs/202410312...  2024-11-01-05:26
# https://wandb.ai/hyena/40b-train/runs/202411022...  2024-11-03-06:47
#
#                                                                  end  \
# https://wandb.ai/hyena/40b-train/runs/202410271...  2024-10-28-00:25
# https://wandb.ai/hyena/40b-train/runs/202410271...  2024-10-28-01:53
# https://wandb.ai/hyena/40b-train/runs/202410280...  2024-10-28-15:35
# https://wandb.ai/hyena/40b-train/runs/202410280...  2024-10-29-00:08
# https://wandb.ai/hyena/40b-train/runs/202410281...  2024-10-29-00:39
# https://wandb.ai/hyena/40b-train/runs/202410281...  2024-10-29-09:28
# https://wandb.ai/hyena/40b-train/runs/202410290...  2024-10-30-05:00
# https://wandb.ai/hyena/40b-train/runs/202410292...  2024-11-01-05:07
# https://wandb.ai/hyena/40b-train/runs/202410312...  2024-11-03-05:26
# https://wandb.ai/hyena/40b-train/runs/202411022...  2024-11-03-09:42
#
#                                                      duration avg_throughput  \
# https://wandb.ai/hyena/40b-train/runs/202410271...      1.045    1355.045421
# https://wandb.ai/hyena/40b-train/runs/202410271...   1.439444    1369.599623
# https://wandb.ai/hyena/40b-train/runs/202410280...   7.982778    1372.898614
# https://wandb.ai/hyena/40b-train/runs/202410280...   7.978611    1355.543759
# https://wandb.ai/hyena/40b-train/runs/202410281...   0.473889    1359.966513
# https://wandb.ai/hyena/40b-train/runs/202410281...   8.785833    1386.274006
# https://wandb.ai/hyena/40b-train/runs/202410290...  17.381667    1404.561807
# https://wandb.ai/hyena/40b-train/runs/202410292...  47.983889     1403.15805
# https://wandb.ai/hyena/40b-train/runs/202410312...  47.985278     1381.53987
# https://wandb.ai/hyena/40b-train/runs/202411022...   2.918611    1385.826899
#
#                                                    avg_iteration_time  \
# https://wandb.ai/hyena/40b-train/runs/202410271...           6.045603
# https://wandb.ai/hyena/40b-train/runs/202410271...            5.98163
# https://wandb.ai/hyena/40b-train/runs/202410280...            5.96716
# https://wandb.ai/hyena/40b-train/runs/202410280...           6.043941
# https://wandb.ai/hyena/40b-train/runs/202410281...           6.023678
# https://wandb.ai/hyena/40b-train/runs/202410281...           5.909985
# https://wandb.ai/hyena/40b-train/runs/202410290...           5.832629
# https://wandb.ai/hyena/40b-train/runs/202410292...            5.83841
# https://wandb.ai/hyena/40b-train/runs/202410312...           5.930307
# https://wandb.ai/hyena/40b-train/runs/202411022...           5.911748
#
#                                                    start_train_loss  \
# https://wandb.ai/hyena/40b-train/runs/202410271...         1.383369
# https://wandb.ai/hyena/40b-train/runs/202410271...         1.345629
# https://wandb.ai/hyena/40b-train/runs/202410280...           1.4619
# https://wandb.ai/hyena/40b-train/runs/202410280...         1.166044
# https://wandb.ai/hyena/40b-train/runs/202410281...          1.11747
# https://wandb.ai/hyena/40b-train/runs/202410281...         1.115309
# https://wandb.ai/hyena/40b-train/runs/202410290...          1.07964
# https://wandb.ai/hyena/40b-train/runs/202410292...         1.052863
# https://wandb.ai/hyena/40b-train/runs/202410312...         1.020522
# https://wandb.ai/hyena/40b-train/runs/202411022...         1.008339
#
#                                                    end_train_loss  \
# https://wandb.ai/hyena/40b-train/runs/202410271...       1.325034
# https://wandb.ai/hyena/40b-train/runs/202410271...       1.278811
# https://wandb.ai/hyena/40b-train/runs/202410280...       1.156094
# https://wandb.ai/hyena/40b-train/runs/202410280...       1.109557
# https://wandb.ai/hyena/40b-train/runs/202410281...        1.11747
# https://wandb.ai/hyena/40b-train/runs/202410281...       1.081061
# https://wandb.ai/hyena/40b-train/runs/202410290...       1.047377
# https://wandb.ai/hyena/40b-train/runs/202410292...       1.023916
# https://wandb.ai/hyena/40b-train/runs/202410312...        1.00833
# https://wandb.ai/hyena/40b-train/runs/202411022...       1.008232
#
#                                                    start_val_loss end_val_loss
# https://wandb.ai/hyena/40b-train/runs/202410271...       1.363242     1.329777
# https://wandb.ai/hyena/40b-train/runs/202410271...       1.350023     1.290337
# https://wandb.ai/hyena/40b-train/runs/202410280...       1.526385     1.187329
# https://wandb.ai/hyena/40b-train/runs/202410280...       1.194547     1.143814
# https://wandb.ai/hyena/40b-train/runs/202410281...       1.147641     1.147641
# https://wandb.ai/hyena/40b-train/runs/202410281...       1.147572     1.117539
# https://wandb.ai/hyena/40b-train/runs/202410290...       1.117321       1.0855
# https://wandb.ai/hyena/40b-train/runs/202410292...       1.086303     1.056264
# https://wandb.ai/hyena/40b-train/runs/202410312...       1.055115     1.043902
# https://wandb.ai/hyena/40b-train/runs/202411022...       1.041133     1.041214

# %%
run.url
# Out:
# 'https://wandb.ai/hyena/40b-train/runs/20241027162236'

# %%
metadata["startedAt"]
# Convert to datetime
from datetime import datetime

datetime.fromisoformat(metadata["startedAt"])
# Out:
# '2024-10-27T23:22:36.668030Z'
# datetime.datetime(2024, 10, 27, 23, 22, 36, 668030, tzinfo=datetime.timezone.utc)

# %%
h = run.scan_history(keys=HISTORY_KEYS)

# %%
df = pd.DataFrame(h)

# %%
df.head()
# Out:
#    _step  data/tokens_per_second_per_gpu  runtime/iteration_time  \
# 0    200                     1351.188812                6.062809
# 1    400                     1358.902030                6.028396
#
#    train/lm_loss  validation/lm_loss
# 0       1.383369            1.363242
# 1       1.325034            1.329777

# %%
runtime = run.summary["_runtime"]
timestamp = run.summary["_timestamp"]

# %%
# convert timestamp to datetime
from datetime import datetime

timestamp = datetime.fromtimestamp(timestamp)

# %%
metadata.keys()
# Out:
# dict_keys(['os', 'python', 'startedAt', 'args', 'program', 'codePath', 'git', 'email', 'root', 'host', 'username', 'executable', 'codePathLocal', 'cpu_count', 'cpu_count_logical', 'gpu', 'gpu_count', 'disk', 'memory', 'cpu', 'gpu_nvidia', 'slurm', 'cudaVersion'])

# %%
duration = run.summary["_wandb"]["runtime"]
